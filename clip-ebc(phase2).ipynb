# %%
# !git clone https://github.com/Yiming-M/CLIP-EBC.git
# Out:
# Cloning into 'CLIP-EBC'...
# remote: Enumerating objects: 403, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 403 (delta 36), reused 27 (delta 27), pack-reused 340 (from 1)
# Receiving objects: 100% (403/403), 13.85 MiB | 3.27 MiB/s, done.
# Resolving deltas: 100% (71/71), done.

# %%
# %cd CLIP-EBC/
# Out:
# /home/gpuuser6/mahek/CLIP-EBC

# %%
pip install -r requirements.txt  # Install the required packages.
# Out:
# Collecting einops==0.7.0 (from -r requirements.txt (line 1))
#   Using cached einops-0.7.0-py3-none-any.whl.metadata (13 kB)
# Collecting ftfy==6.1.3 (from -r requirements.txt (line 2))
#   Downloading ftfy-6.1.3-py3-none-any.whl.metadata (6.2 kB)
# Collecting numpy==1.26.4 (from -r requirements.txt (line 3))
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting Pillow==10.2.0 (from -r requirements.txt (line 4))
#   Downloading pillow-10.2.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Collecting regex==2023.12.25 (from -r requirements.txt (line 5))
#   Downloading regex-2023.12.25-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting scipy==1.12.0 (from -r requirements.txt (line 6))
#   Downloading scipy-1.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting setuptools==69.1.1 (from -r requirements.txt (line 7))
#   Downloading setuptools-69.1.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting tensorboardX==2.6.2.2 (from -r requirements.txt (line 8))
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting timm==0.9.16 (from -r requirements.txt (line 10))
#   Downloading timm-0.9.16-py3-none-any.whl.metadata (38 kB)
# Collecting torch==2.2.1 (from -r requirements.txt (line 11))
#   Downloading torch-2.2.1-cp312-cp312-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchvision==0.17.1 (from -r requirements.txt (line 12))
#   Downloading torchvision-0.17.1-cp312-cp312-manylinux1_x86_64.whl.metadata (6.6 kB)
# Collecting tqdm==4.66.2 (from -r requirements.txt (line 13))
#   Downloading tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
# Collecting wcwidth<0.3.0,>=0.2.12 (from ftfy==6.1.3->-r requirements.txt (line 2))
#   Using cached wcwidth-0.2.14-py2.py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from tensorboardX==2.6.2.2->-r requirements.txt (line 8)) (25.0)
# Collecting protobuf>=3.20 (from tensorboardX==2.6.2.2->-r requirements.txt (line 8))
#   Using cached protobuf-7.34.0-cp310-abi3-manylinux2014_x86_64.whl.metadata (595 bytes)
# Collecting pyyaml (from timm==0.9.16->-r requirements.txt (line 10))
#   Using cached pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting huggingface_hub (from timm==0.9.16->-r requirements.txt (line 10))
#   Using cached huggingface_hub-1.7.1-py3-none-any.whl.metadata (13 kB)
# Collecting safetensors (from timm==0.9.16->-r requirements.txt (line 10))
#   Using cached safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting filelock (from torch==2.2.1->-r requirements.txt (line 11))
#   Using cached filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from torch==2.2.1->-r requirements.txt (line 11)) (4.15.0)
# Collecting sympy (from torch==2.2.1->-r requirements.txt (line 11))
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch==2.2.1->-r requirements.txt (line 11))
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch==2.2.1->-r requirements.txt (line 11))
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch==2.2.1->-r requirements.txt (line 11))
#   Using cached fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.2.1->-r requirements.txt (line 11))
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.2.1->-r requirements.txt (line 11))
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.2.1->-r requirements.txt (line 11))
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.2.1->-r requirements.txt (line 11))
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.2.1->-r requirements.txt (line 11))
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.2.1->-r requirements.txt (line 11))
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.2.1->-r requirements.txt (line 11))
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.2.1->-r requirements.txt (line 11))
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.2.1->-r requirements.txt (line 11))
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch==2.2.1->-r requirements.txt (line 11))
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.2.1->-r requirements.txt (line 11))
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.1->-r requirements.txt (line 11))
#   Using cached nvidia_nvjitlink_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting hf-xet<2.0.0,>=1.4.2 (from huggingface_hub->timm==0.9.16->-r requirements.txt (line 10))
#   Using cached hf_xet-1.4.2-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Collecting httpx<1,>=0.23.0 (from huggingface_hub->timm==0.9.16->-r requirements.txt (line 10))
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting typer (from huggingface_hub->timm==0.9.16->-r requirements.txt (line 10))
#   Using cached typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Collecting anyio (from httpx<1,>=0.23.0->huggingface_hub->timm==0.9.16->-r requirements.txt (line 10))
#   Using cached anyio-4.12.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting certifi (from httpx<1,>=0.23.0->huggingface_hub->timm==0.9.16->-r requirements.txt (line 10))
#   Using cached certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->huggingface_hub->timm==0.9.16->-r requirements.txt (line 10))
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx<1,>=0.23.0->huggingface_hub->timm==0.9.16->-r requirements.txt (line 10))
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->timm==0.9.16->-r requirements.txt (line 10))
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch==2.2.1->-r requirements.txt (line 11))
#   Using cached markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch==2.2.1->-r requirements.txt (line 11))
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting click>=8.2.1 (from typer->huggingface_hub->timm==0.9.16->-r requirements.txt (line 10))
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer->huggingface_hub->timm==0.9.16->-r requirements.txt (line 10))
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer->huggingface_hub->timm==0.9.16->-r requirements.txt (line 10))
#   Using cached rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer->huggingface_hub->timm==0.9.16->-r requirements.txt (line 10))
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer->huggingface_hub->timm==0.9.16->-r requirements.txt (line 10))
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from rich>=12.3.0->typer->huggingface_hub->timm==0.9.16->-r requirements.txt (line 10)) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub->timm==0.9.16->-r requirements.txt (line 10))
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached einops-0.7.0-py3-none-any.whl (44 kB)
# Downloading ftfy-6.1.3-py3-none-any.whl (53 kB)
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 7.7 MB/s  0:00:02m0:00:0100:01m
# Downloading pillow-10.2.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 2.1 MB/s  0:00:02 eta 0:00:01
# Downloading regex-2023.12.25-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (789 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 789.1/789.1 kB 2.0 MB/s  0:00:00 eta 0:00:01
# Downloading scipy-1.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.8/37.8 MB 657.9 kB/s  0:00:56m0:00:0100:02
# Downloading setuptools-69.1.1-py3-none-any.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.3/819.3 kB 703.8 kB/s  0:00:01eta 0:00:01
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
# Downloading timm-0.9.16-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 728.5 kB/s  0:00:03 eta 0:00:01
# Downloading torch-2.2.1-cp312-cp312-manylinux1_x86_64.whl (755.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 634.9 kB/s  0:17:560:00:0100:28
# Downloading torchvision-0.17.1-cp312-cp312-manylinux1_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 692.5 kB/s  0:00:10m0:00:0100:01
# Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 878.4 kB/s  0:03:380:00:0100:06
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Using cached wcwidth-0.2.14-py2.py3-none-any.whl (37 kB)
# Using cached protobuf-7.34.0-cp310-abi3-manylinux2014_x86_64.whl (324 kB)
# Using cached filelock-3.25.2-py3-none-any.whl (26 kB)
# Using cached fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Using cached huggingface_hub-1.7.1-py3-none-any.whl (616 kB)
# Using cached hf_xet-1.4.2-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.2 MB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (807 kB)
# Using cached anyio-4.12.1-py3-none-any.whl (113 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (22 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached nvidia_nvjitlink_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.7 MB)
# Using cached safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached typer-0.24.1-py3-none-any.whl (56 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Using cached rich-14.3.3-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: mpmath, wcwidth, tqdm, sympy, shellingham, setuptools, safetensors, regex, pyyaml, protobuf, Pillow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, mdurl, MarkupSafe, idna, hf-xet, h11, fsspec, filelock, einops, click, certifi, annotated-doc, tensorboardX, scipy, nvidia-cusparse-cu12, nvidia-cudnn-cu12, markdown-it-py, jinja2, httpcore, ftfy, anyio, rich, nvidia-cusolver-cu12, httpx, typer, torch, torchvision, huggingface_hub, timm
#   Attempting uninstall: wcwidth━━━━━━━━━━━━━━━━━  0/50 [mpmath]
#     Found existing installation: wcwidth 0.6.00m  0/50 [mpmath]
#     Uninstalling wcwidth-0.6.0:━━━━━━━━━━━━━  0/50 [mpmath]
#       Successfully uninstalled wcwidth-0.6.0  0/50 [mpmath]
#   Attempting uninstall: tqdm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/50 [wcwidth]
#     Found existing installation: tqdm 4.67.3━━━━━━━━━  1/50 [wcwidth]
#     Uninstalling tqdm-4.67.3:━━━━━━━━━━━━━━━━━━━━━━━━  1/50 [wcwidth]
#       Successfully uninstalled tqdm-4.67.3━━━━━━━━━━━  1/50 [wcwidth]
#   Attempting uninstall: setuptools━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/50 [sympy]
#     Found existing installation: setuptools 80.10.2━━━━━━━━━━━  3/50 [sympy]
#     Uninstalling setuptools-80.10.2:━━━━━━━━━━━━━━━━━━━━━━━━━━  3/50 [sympy]
#       Successfully uninstalled setuptools-80.10.2━━━━━━━━━━━━━━━━━  5/50 [setuptools]
#   Attempting uninstall: Pillow━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  9/50 [protobuf]s]
#     Found existing installation: pillow 12.1.1━━━━━━━━━━━━━━━━  9/50 [protobuf]
#     Uninstalling pillow-12.1.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  9/50 [protobuf]
#       Successfully uninstalled pillow-12.1.1━━━━━━━━━━━━━━━━━━  9/50 [protobuf]
#   Attempting uninstall: numpy90m╺━━━━━━━━━━━━━━━━━━━━━━━━ 19/50 [nvidia-cublas-cu12]u12]2]
#     Found existing installation: numpy 2.4.2━━━━━━━━━━━━━━━━━━ 19/50 [nvidia-cublas-cu12]
#     Uninstalling numpy-2.4.2:━━━━━━━━━━━━━━━━━━━━━━━━ 19/50 [nvidia-cublas-cu12]
#       Successfully uninstalled numpy-2.4.2━━━━━━━━━━━━━━━━━━━━ 19/50 [nvidia-cublas-cu12]
#   Attempting uninstall: scipy━━━━━╺━━━━━━━━━━━━━ 33/50 [tensorboardX]2]
#     Found existing installation: scipy 1.17.0━━━━━━━━━━━━━ 33/50 [tensorboardX]
#     Uninstalling scipy-1.17.0:╺━━━━━━━━━━━━━ 33/50 [tensorboardX]
#       Successfully uninstalled scipy-1.17.0m━━━━━━━━━━━━━ 33/50 [tensorboardX]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50/50 [timm]0m [timm]0m [huggingface_hub]cu12]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed MarkupSafe-3.0.3 Pillow-10.2.0 annotated-doc-0.0.4 anyio-4.12.1 certifi-2026.2.25 click-8.3.1 einops-0.7.0 filelock-3.25.2 fsspec-2026.2.0 ftfy-6.1.3 h11-0.16.0 hf-xet-1.4.2 httpcore-1.0.9 httpx-0.28.1 huggingface_hub-1.7.1 idna-3.11 jinja2-3.1.6 markdown-it-py-4.0.0 mdurl-0.1.2 mpmath-1.3.0 networkx-3.6.1 numpy-1.26.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.9.86 nvidia-nvtx-cu12-12.1.105 protobuf-7.34.0 pyyaml-6.0.3 regex-2023.12.25 rich-14.3.3 safetensors-0.7.0 scipy-1.12.0 setuptools-69.1.1 shellingham-1.5.4 sympy-1.14.0 tensorboardX-2.6.2.2 timm-0.9.16 torch-2.2.1 torchvision-0.17.1 tqdm-4.66.2 typer-0.24.1 wcwidth-0.2.14
# Note: you may need to restart the kernel to use updated packages.

# %%
# !nvidia-smi
# Out:
# Thu Mar 19 07:32:26 2026
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.129.06   Driver Version: 470.129.06   CUDA Version: 12.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  On   | 00000000:B7:00.0 Off |                    0 |
# | N/A   43C    P0    71W / 400W |  16149MiB / 81251MiB |      1%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
# !pip install ftfy regex tqdm
# !pip install git+https://github.com/openai/CLIP.git
# Out:
# Requirement already satisfied: ftfy in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (6.1.3)
# Requirement already satisfied: regex in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (2023.12.25)
# Requirement already satisfied: tqdm in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (4.66.2)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from ftfy) (0.2.14)
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-dpfd7clg
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-dpfd7clg
#   Resolved https://github.com/openai/CLIP.git to commit ded190a052fdf4585bd685cee5bc96e0310d2c93
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: ftfy in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from clip==1.0) (6.1.3)
# Requirement already satisfied: packaging in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from clip==1.0) (25.0)
# Requirement already satisfied: regex in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from clip==1.0) (2023.12.25)
# Requirement already satisfied: tqdm in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from clip==1.0) (4.66.2)
# Requirement already satisfied: torch in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from clip==1.0) (2.2.1)
# Requirement already satisfied: torchvision in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from clip==1.0) (0.17.1)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from ftfy->clip==1.0) (0.2.14)
# Requirement already satisfied: filelock in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from torch->clip==1.0) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from torch->clip==1.0) (4.15.0)
# Requirement already satisfied: sympy in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from torch->clip==1.0) (1.14.0)
# Requirement already satisfied: networkx in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from torch->clip==1.0) (3.6.1)
# Requirement already satisfied: jinja2 in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from torch->clip==1.0) (3.1.6)
# Requirement already satisfied: fsspec in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from torch->clip==1.0) (2026.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from torch->clip==1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from torch->clip==1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from torch->clip==1.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from torch->clip==1.0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from torch->clip==1.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from torch->clip==1.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from torch->clip==1.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from torch->clip==1.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from torch->clip==1.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from torch->clip==1.0) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from torch->clip==1.0) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->clip==1.0) (12.9.86)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from jinja2->torch->clip==1.0) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from sympy->torch->clip==1.0) (1.3.0)
# Requirement already satisfied: numpy in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from torchvision->clip==1.0) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/site-packages (from torchvision->clip==1.0) (10.2.0)
# Building wheels for collected packages: clip
#   Building wheel for clip (pyproject.toml) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369549 sha256=494504b0cca2562002bb9fbf39eaa30cd5f5002a76b26efcc6cf18cead914f35
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6mnqlnsx/wheels/35/3e/df/3d24cbfb3b6a06f17a2bfd7d1138900d4365d9028aa8f6e92f
# Successfully built clip
# Installing collected packages: clip
# Successfully installed clip-1.0

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.2.1+cu121
# True

# %%
# !bash preprocess.sh
# Out:
# Pre-processing sha dataset...
# Processing train...
# 100%|████████████████████████████████████████| 300/300 [00:02<00:00, 123.58it/s]
# Processing val...
# 100%|████████████████████████████████████████| 182/182 [00:01<00:00, 124.60it/s]

# %%
# !python trainer.py \
    --model clip_resnet50 --input_size 448 --reduction 8 --truncation 4 --anchor_points average --prompt_type word \
    --dataset sha \
    --count_loss dmcount
# Out:
# Preparing CLIP models...
#  22%|██████████                                   | 2/9 [00:29<01:45, 15.10s/it]
#   0%|                                               | 0.00/402M [00:00<?, ?iB/s]
#   0%|                                       | 64.0k/402M [00:00<10:52, 646kiB/s]
#   0%|                                        | 128k/402M [00:00<15:32, 452kiB/s]
#   0%|                                        | 176k/402M [00:00<19:38, 358kiB/s]
#   0%|                                        | 224k/402M [00:00<23:50, 295kiB/s]
#   0%|                                        | 352k/402M [00:00<17:13, 408kiB/s]
#   0%|                                        | 448k/402M [00:01<16:44, 420kiB/s]
#   0%|                                        | 576k/402M [00:01<22:39, 310kiB/s]
#   0%|                                        | 768k/402M [00:01<13:42, 512kiB/s]
#   0%|                                        | 944k/402M [00:02<11:52, 590kiB/s]
#   0%|                                       | 1.11M/402M [00:02<10:19, 680kiB/s]
#   1%|▏                                     | 2.12M/402M [00:02<03:07, 2.23MiB/s]
#   1%|▏                                     | 2.59M/402M [00:02<02:38, 2.65MiB/s]
#   1%|▎                                     | 2.98M/402M [00:02<02:34, 2.72MiB/s]
#   2%|▌                                     | 6.09M/402M [00:02<00:45, 9.04MiB/s]
#   2%|▋                                     | 7.28M/402M [00:02<00:42, 9.70MiB/s]
#   2%|▊                                     | 8.45M/402M [00:06<06:15, 1.10MiB/s]
#   2%|▉                                      | 9.27M/402M [00:07<07:42, 892kiB/s]
#   3%|▉                                     | 10.4M/402M [00:08<05:30, 1.24MiB/s]
#   3%|█                                     | 11.5M/402M [00:08<03:59, 1.71MiB/s]
#   3%|█▏                                    | 12.6M/402M [00:08<02:57, 2.30MiB/s]
#   3%|█▎                                    | 13.8M/402M [00:08<02:12, 3.07MiB/s]
#   4%|█▍                                    | 14.9M/402M [00:08<01:43, 3.93MiB/s]
#   4%|█▌                                    | 16.0M/402M [00:10<04:07, 1.64MiB/s]
#   4%|█▌                                    | 16.8M/402M [00:11<06:43, 1.00MiB/s]
#   4%|█▋                                    | 17.3M/402M [00:12<06:31, 1.03MiB/s]
#   4%|█▋                                    | 17.7M/402M [00:12<06:08, 1.09MiB/s]
#   5%|█▊                                    | 18.8M/402M [00:12<03:56, 1.70MiB/s]
#   5%|█▉                                    | 20.0M/402M [00:12<02:39, 2.51MiB/s]
#   5%|█▉                                    | 21.1M/402M [00:12<01:57, 3.39MiB/s]
#   6%|██                                    | 22.2M/402M [00:13<01:29, 4.46MiB/s]
#   6%|██▎                                   | 24.2M/402M [00:15<04:03, 1.63MiB/s]
#  22%|██████████                                   | 2/9 [00:47<02:46, 23.76s/it]
# Traceback (most recent call last):
#   File "/home/gpuuser6/mahek/CLIP-EBC/trainer.py", line 13, in <module>
#     from models import get_model
#   File "/home/gpuuser6/mahek/CLIP-EBC/models/__init__.py", line 4, in <module>
#     from .clip import _clip_ebc, CLIP_EBC
#   File "/home/gpuuser6/mahek/CLIP-EBC/models/clip/__init__.py", line 1, in <module>
#     from .model import CLIP_EBC, _clip_ebc
#   File "/home/gpuuser6/mahek/CLIP-EBC/models/clip/model.py", line 9, in <module>
#     from . import _clip
#   File "/home/gpuuser6/mahek/CLIP-EBC/models/clip/_clip/__init__.py", line 35, in <module>
#     prepare()
#   File "/home/gpuuser6/mahek/CLIP-EBC/models/clip/_clip/prepare.py", line 53, in prepare
#     model = load(model_name, device=device).to(device)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gpuuser6/mahek/CLIP-EBC/models/clip/_clip/utils.py", line 124, in load
#     model_path = _download(_MODELS[name], download_root or os.path.expanduser("~/.cache/clip"))
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gpuuser6/mahek/CLIP-EBC/models/clip/_clip/utils.py", line 66, in _download
#     buffer = source.read(8192)
#              ^^^^^^^^^^^^^^^^^
#   File "/home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/http/client.py", line 479, in read
#     s = self.fp.read(amt)
#         ^^^^^^^^^^^^^^^^^
#   File "/home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/socket.py", line 720, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/ssl.py", line 1251, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gpuuser6/miniconda3/envs/mahek/lib/python3.12/ssl.py", line 1103, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C
